# %% [markdown]
# BASICS OF PYTHON
#
# > Conditional statements, Boolean expressions

# %%
x = int(input("what is x ?"))
y = int(input("what is y ?"))

if x < y:
  print('x is less than y')
elif x > y:
  print('x is greater than y')
elif x == y:
  print('x is equal to y')
else:
  print("wrong input")
# Out:
# what is x ?34
# what is y ?65
# x is less than y

# %%
x = int(input("what is x ?"))
y = int(input("what is y ?"))

if x < y or x > y:
  print('x is not equal to y')
else:
  print('x is equal to y')
# Out:
# what is x ?78
# what is y ?57
# x is not equal to y

# %%
score = int(input("what is your score ?"))

if score >= 90 and score <= 100:
  print('A')
elif score >= 80 and score <= 89:
  print('B')
elif score>=70 and score <79:
  print('C')
elif score>=60 and score <69:
  print('D')
elif score>=50 and score <59:
  print('E')
else:
  print('F')
# Out:
# what is your score ?76
# C

# %%
x=int(input("what is x?"))

if x%2==0:
  print("even")
else:
  print("odd")
# Out:
# what is x?665
# odd

# %%
def main():
  x=int(input("what is x?"))
  if is_even(x):
    print("even")
  else:
    print("odd")

def is_even(n):
  if n%2==0:
    return True
  else:
    return False

main()
is_even(x)
# Out:
# what is x?643
# odd
# False

# %%
def main():
    greeting = input("Greeting: ").strip().lower()

    if greeting.startswith("hello"):
        print("$0")
    elif greeting.startswith("h"):
        print("$20")
    else:
        print("$100")

main()
# Out:
# Greeting: hi
# $20

# %%
name= input("what is your name?")

if name == "Harry":
  print("Gryffindor")
elif name == "Hermione":
  print("Gryffindor")
elif name == "Ron":
  print("Gryffindor")
elif name == "Draco":
  print("Slytherin")
else:
  print("who?")
# Out:
# what is your name?pratham
# who?

# %%
name= input("what is your name?")

match name:
  case "Harry":
    print("Gryffindor")
  case "Hermione":
    print("Gryffindor")
  case "Ron":
    print("Gryffindor")
  case "Draco":
    print("Slytherin")
  case _:
    print("who?")
# Out:
# what is your name?jcy
# who?

# %%
def main():
    try:
        expression = input("Expression: ").strip()
        x, operator, z = expression.split()

        x = int(x)
        z = int(z)

        if operator == "+":
            result = x + z
        elif operator == "-":
            result = x - z
        elif operator == "*":
            result = x * z
        elif operator == "/":
            result = x / z
        else:
            raise ValueError("Invalid operator")

        print(f"{result:.1f}")

    except ValueError:
        print("Invalid input. Please enter in the format: x operator z (e.g., 3 + 4)")

main()
# Out:
# Expression: 22 + 23
# 45.0

# %%
def main():
    filename = input("File name: ").strip().lower()

    if filename.endswith(".gif"):
        print("image/gif")
    elif filename.endswith(".jpg") or filename.endswith(".jpeg"):
        print("image/jpeg")
    elif filename.endswith(".png"):
        print("image/png")
    elif filename.endswith(".pdf"):
        print("application/pdf")
    elif filename.endswith(".txt"):
        print("text/plain")
    elif filename.endswith(".zip"):
        print("application/zip")
    else:
        print("application/octet-stream")

main()
# Out:
# File name: app.zip
# application/zip

# %%
def main():
    time_str = input("What time is it? ")
    time = convert(time_str)

    if 7 <= time <= 8:
        print("breakfast time")
    elif 12 <= time <= 13:
        print("lunch time")
    elif 18 <= time <= 19:
        print("dinner time")


def convert(time):
    hours, minutes = time.strip().split(":")
    hours = int(hours)
    minutes = int(minutes)
    return hours + minutes / 60


if __name__ == "__main__":
    main()
# Out:
# What time is it? 11:45

# %%
def main():
  difficulty = input("Diificult or casual?")
  if not (difficulty == "Difficult" or difficulty == "Casual"):
    print("wrong input")
    return
  players = input("Multiplayer or single player?")
  if not (players == "Multiplayer" or players == "Singleplayer"):
    print("wrong input")
    return

  if difficulty == "difficult" and players == "Multiplayer":
    recommend("VALORANT")
  elif difficulty == "difficult" and players == "Singleplayer":
    recommend("COD")
  elif difficulty == "casual" and players == "Multiplayer":
    recommend("NFS")
  else:
    recommend("GTA")


def recommend(game):
  print("you might like",game)

main()
# Out:
# Diificult or casual?Casual
# Multiplayer or single player?Singleplayer
# you might like GTA
